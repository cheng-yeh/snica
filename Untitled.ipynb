# %%
import numpy as np
import scipy as sc
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
# Specify the path to the pickle file
x_path = "data/alice_eeg/24chans.pkl"
f_path = "data/alice_eeg/24chans_f_n3_k1_d1.pkl"

with open(x_path, 'rb') as f:
    x = pickle.load(f)
    print("x.shape: ", x.shape)

with open(z_path, 'rb') as f:
    z = pickle.load(f)
    print("z.shape: ", z.shape)
# Out:
# x.shape:  (24, 73305)
# z.shape:  (24, 73305)

# %%
for e in range(x.shape[0]):
    plt.plot(x[e, 10000:10050])

# %%
#for e in range(z.shape[0]):
for e in range(10):
    #plt.plot(z[e,22000:22050])
    plt.plot(z[e, 10000:10050])

# %%
sc.signal.periodogram(z[0])
# Out:
# (array([0.00000000e+00, 1.36416343e-05, 2.72832685e-05, ...,
#         4.99965896e-01, 4.99979538e-01, 4.99993179e-01]),
#  array([5.6025330e-15, 1.7879267e-03, 6.0205380e-03, ..., 8.3914129e-03,
#         1.7102506e-02, 4.0941434e-03], dtype=float32))

# %%
fs = 100
#for e in range(z.shape[0]):
for e in range(3,4):
    f, t, Sxx = sc.signal.spectrogram(z[e], fs)
    plt.pcolormesh(t, f, Sxx, shading='gouraud')

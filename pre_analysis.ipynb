# %%
import numpy as np
import scipy as sc
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
# Specify the path to the pickle file
x_path = "data/alice_eeg/24chans.pkl"
x_path = "data/alice_eeg/24chans_fmin5_fmax5000_rwin100_samp100.pkl"
fz_path = "data/alice_eeg/24chans_f_n3_k2_d6.pkl"
z_path = "data/alice_eeg/24chans_z_n3_k2_d6.pkl"

with open(x_path, 'rb') as f:
    x = pickle.load(f)
    print("x.shape: ", x.shape)

with open(fz_path, 'rb') as f:
    fz = pickle.load(f)
    print("fz.shape: ", fz.shape)

with open(z_path, 'rb') as f:
    z = pickle.load(f)
    print("z.shape: ", z.shape)
# Out:
# x.shape:  (24, 73305)
# fz.shape:  (24, 3666)
# z.shape:  (3, 3666)

# %%
for e in range(x.shape[0]):
    #plt.plot(x[e,22000:23050])
    plt.plot(x[e, 100:200])

# %%
#for e in range(fz.shape[0]):
for e in range(24):
    #plt.plot(fz[e,22000:23050])
    plt.plot(fz[e, 100:200])

# %%
for e in range(z.shape[0]):
    #plt.plot(z[e,22000:22050])
    #plt.plot(z[e, 10000:10050])
    plt.plot(z[e, 100:200])

# %%
sc.signal.periodogram(z[0])

# %%
fs = 100
#for e in range(z.shape[0]):
for e in range(3,4):
    f, t, Sxx = sc.signal.spectrogram(z[e], fs)
    plt.pcolormesh(t, f, Sxx, shading='gouraud')
